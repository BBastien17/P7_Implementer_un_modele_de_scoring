# %% [markdown]
# ### Importation des librairies

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
#Traitement des messages d'erreur :
warnings.filterwarnings('ignore')

import sklearn
#Librairie pour créer un dataset de train et un de test
from sklearn.model_selection import train_test_split
#Librairie pour l'encodage des variables catégorielles
from sklearn.preprocessing import LabelEncoder
#Librairies pour réaliser un pipeline
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import RobustScaler, OneHotEncoder

# %% [markdown]
# ### Fonctions utilisées dans le notebook

# %%
#Fonction pour préparer le pipeline qui traitera les variables numériques
def Preprocessing (numeric):
    """Fonction pour préparer le pipeline afin de pouvoir traiter les variables numériques"""
    #On prend la médiane concernant le traitement des Nan et on standardise les données à l'aide de RobustScaler
    #Ce Scaler supprime la médiane et met à l'échelle les données en fonction de l'intervalle des quantiles
    numeric_transfs = [('imputer',SimpleImputer(missing_values= np.NAN, strategy= 'median')),('scaler', RobustScaler())]
    numeric_pipeline = Pipeline(numeric_transfs)
    all_transfs = [("numeric",numeric_pipeline,numeric)]
    full_preprocessor = ColumnTransformer(all_transfs, remainder='passthrough')
    return full_preprocessor

# %% [markdown]
# ### Lecture du dataset

# %%
path = 'Projet_7/'
data_work = pd.read_csv(path + "data_final.csv")

# %%
display(data_work.head())
print("Voici la taille du dataset : ", data_work.shape)
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER  CNT_CHILDREN  \
# 0      100002       1         Cash loans           M             0
# 1      100003       0         Cash loans           F             0
# 2      100004       0    Revolving loans           M             0
# 3      100006       0         Cash loans           F             0
# 4      100007       0         Cash loans           M             0
#
#    AMT_INCOME_TOTAL  AMT_CREDIT_x NAME_TYPE_SUITE NAME_INCOME_TYPE  \
# 0          202500.0      406597.5   Unaccompanied          working
# 1          270000.0     1293502.5          Family          working
# 2           67500.0      135000.0   Unaccompanied          working
# 3          135000.0      312682.5   Unaccompanied          working
# 4          121500.0      513000.0   Unaccompanied          working
#
#     NAME_EDUCATION_TYPE  ... DAYS_DECISION  CNT_PAYMENT  DAYS_FIRST_DRAWING  \
# 0   low_level_education  ...   -606.000000    24.000000            365243.0
# 1  high_level_education  ...  -1305.000000    10.000000            365243.0
# 2   low_level_education  ...   -815.000000     4.000000            365243.0
# 3   low_level_education  ...   -272.444444    23.000000            365243.0
# 4   low_level_education  ...  -1222.833333    20.666667            365243.0
#
#    DAYS_LAST_DUE  DAYS_TERMINATION NAME_CONTRACT_STATUS  CODE_REJECT_REASON  \
# 0     -25.000000        -17.000000             Approved                 XAP
# 1   -1054.333333      -1047.333333             Approved                 XAP
# 2    -724.000000       -714.000000             Approved                 XAP
# 3  182477.500000     182481.750000             Approved                 XAP
# 4   72136.200000      72143.800000             Approved                 XAP
#
#    NAME_CLIENT_TYPE  CNT_INSTALMENT_FUTURE  SK_DPD_y
# 0               New              15.000000       0.0
# 1         Refreshed               4.909091       0.0
# 2               New               0.000000       0.0
# 3          Repeater               8.650000       0.0
# 4          Repeater              11.666667       0.0
#
# [5 rows x 47 columns]
# Voici la taille du dataset :  (307511, 47)

# %% [markdown]
# ### Préparation des différents datasets

# %%
#On crée une variable pour stocker le nombre de lignes du dataset
train_len = data_work.shape[0]
print(train_len)
# Out:
# 307511

# %%
#On crée un dataset qui stockera la variable SK_ID_CURR et on la supprimera du dataset de train
train_dataset = data_work[:train_len]
train_ids = train_dataset['SK_ID_CURR']
train_dataset.drop(columns=['SK_ID_CURR'], axis = 1, inplace=True)

# %%
#On crée 2 datasets, un pour les variables utilisées pour la modélisation et un autre pour stocker la variable
#que l'on souhaite prédire
train_dataset['TARGET'] = train_dataset['TARGET'].astype(int)
target = train_dataset['TARGET']
features = train_dataset.drop(columns=['TARGET'], axis = 1)
print('x_train data shape: ', features.shape)
print('y_train data shape: ', target.shape)

#Export des dataset target et features en CSV pour utilisation de la fonction SMOTE ultérieurement
target.to_csv(path + 'target.csv',index=False)
features.to_csv(path + 'features.csv',index=False)
# Out:
# x_train data shape:  (307511, 45)
# y_train data shape:  (307511,)

# %%
target.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 307511 entries, 0 to 307510
# Series name: TARGET
# Non-Null Count   Dtype
# --------------   -----
# 307511 non-null  int32
# dtypes: int32(1)
# memory usage: 1.2 MB

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Data columns (total 45 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   NAME_CONTRACT_TYPE           307511 non-null  object
#  1   CODE_GENDER                  307511 non-null  object
#  2   CNT_CHILDREN                 307511 non-null  int64
#  3   AMT_INCOME_TOTAL             307511 non-null  float64
#  4   AMT_CREDIT_x                 307511 non-null  float64
#  5   NAME_TYPE_SUITE              306219 non-null  object
#  6   NAME_INCOME_TYPE             307511 non-null  object
#  7   NAME_EDUCATION_TYPE          307511 non-null  object
#  8   NAME_FAMILY_STATUS           307511 non-null  object
#  9   REGION_POPULATION_RELATIVE   307511 non-null  float64
#  10  DAYS_BIRTH                   307511 non-null  int64
#  11  DAYS_EMPLOYED                307511 non-null  int64
#  12  OWN_CAR_AGE                  104582 non-null  float64
#  13  OCCUPATION_TYPE              211120 non-null  object
#  14  CNT_FAM_MEMBERS              307509 non-null  float64
#  15  REGION_RATING_CLIENT         307511 non-null  int64
#  16  REGION_RATING_CLIENT_W_CITY  307511 non-null  int64
#  17  HOUR_APPR_PROCESS_START      307511 non-null  int64
#  18  REG_CITY_NOT_WORK_CITY       307511 non-null  int64
#  19  TOTALAREA_MODE               159080 non-null  float64
#  20  DEF_30_CNT_SOCIAL_CIRCLE     306490 non-null  float64
#  21  FLAG_DOCUMENT_3              307511 non-null  int64
#  22  AMT_REQ_CREDIT_BUREAU_YEAR   265992 non-null  float64
#  23  CREDIT_ACTIVE                263491 non-null  object
#  24  DAYS_CREDIT                  263491 non-null  float64
#  25  AMT_CREDIT_SUM               263490 non-null  float64
#  26  AMT_BALANCE                  86905 non-null   float64
#  27  AMT_PAYMENT_CURRENT          61060 non-null   float64
#  28  SK_DPD_x                     86905 non-null   float64
#  29  SK_DPD_DEF                   86905 non-null   float64
#  30  DAYS_INSTALMENT_delay        251957 non-null  float64
#  31  AMT_INSTALMENT_delta         251957 non-null  float64
#  32  AMT_ANNUITY                  290640 non-null  float64
#  33  AMT_CREDIT_y                 291057 non-null  float64
#  34  AMT_DOWN_PAYMENT             273605 non-null  float64
#  35  DAYS_DECISION                291057 non-null  float64
#  36  CNT_PAYMENT                  290642 non-null  float64
#  37  DAYS_FIRST_DRAWING           289760 non-null  float64
#  38  DAYS_LAST_DUE                289760 non-null  float64
#  39  DAYS_TERMINATION             289760 non-null  float64
#  40  NAME_CONTRACT_STATUS         291057 non-null  object
#  41  CODE_REJECT_REASON           291057 non-null  object
#  42  NAME_CLIENT_TYPE             291057 non-null  object
#  43  CNT_INSTALMENT_FUTURE        245251 non-null  float64
#  44  SK_DPD_y                     245434 non-null  float64
# dtypes: float64(26), int64(8), object(11)
# memory usage: 105.6+ MB

# %% [markdown]
# ### Preprocessing

# %%
#On commence par diviser le dataset en un dataset de train et un dataset de test avec une proportion de 80% / 20%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size = 0.2)

# %%
#On remet la variable concernant une période sous un format positif
X_test['DAYS_INSTALMENT_delay'] = X_test['DAYS_INSTALMENT_delay'].mul(-1)

# %%
#On remet la variable concernant une période sous un format positif
X_train['DAYS_INSTALMENT_delay'] = X_train['DAYS_INSTALMENT_delay'].mul(-1)

# %%
#Création de dataframe avec X_test, y_train et y_test que l'on sauvegarde au format .CSV
pd.DataFrame(X_test).to_csv(path + 'X_test.csv',index=False)
pd.DataFrame(y_train).to_csv(path + 'y_train.csv',index=False)
pd.DataFrame(y_test).to_csv(path + 'y_test.csv',index=False)

# %%
#Création d'une variable avec la liste des colonnes catégorielles du dataset features
data_categ = list(features.select_dtypes(exclude=["number"]).columns)
#Création d'une variable avec la liste des colonnes numériques du dataset features
data_num = list(features.select_dtypes(exclude=["bool_","object_"]).columns)

# %%
print("Voici la liste des colonnes catégorielles : ")
data_categ
# Out:
# Voici la liste des colonnes catégorielles :
# ['NAME_CONTRACT_TYPE',
#  'CODE_GENDER',
#  'NAME_TYPE_SUITE',
#  'NAME_INCOME_TYPE',
#  'NAME_EDUCATION_TYPE',
#  'NAME_FAMILY_STATUS',
#  'OCCUPATION_TYPE',
#  'CREDIT_ACTIVE',
#  'NAME_CONTRACT_STATUS',
#  'CODE_REJECT_REASON',
#  'NAME_CLIENT_TYPE']

# %%
print("Voici la liste des colonnes numériques : ")
data_num
# Out:
# Voici la liste des colonnes numériques :
# ['CNT_CHILDREN',
#  'AMT_INCOME_TOTAL',
#  'AMT_CREDIT_x',
#  'REGION_POPULATION_RELATIVE',
#  'DAYS_BIRTH',
#  'DAYS_EMPLOYED',
#  'OWN_CAR_AGE',
#  'CNT_FAM_MEMBERS',
#  'REGION_RATING_CLIENT',
#  'REGION_RATING_CLIENT_W_CITY',
#  'HOUR_APPR_PROCESS_START',
#  'REG_CITY_NOT_WORK_CITY',
#  'TOTALAREA_MODE',
#  'DEF_30_CNT_SOCIAL_CIRCLE',
#  'FLAG_DOCUMENT_3',
#  'AMT_REQ_CREDIT_BUREAU_YEAR',
#  'DAYS_CREDIT',
#  'AMT_CREDIT_SUM',
#  'AMT_BALANCE',
#  'AMT_PAYMENT_CURRENT',
#  'SK_DPD_x',
#  'SK_DPD_DEF',
#  'DAYS_INSTALMENT_delay',
#  'AMT_INSTALMENT_delta',
#  'AMT_ANNUITY',
#  'AMT_CREDIT_y',
#  'AMT_DOWN_PAYMENT',
#  'DAYS_DECISION',
#  'CNT_PAYMENT',
#  'DAYS_FIRST_DRAWING',
#  'DAYS_LAST_DUE',
#  'DAYS_TERMINATION',
#  'CNT_INSTALMENT_FUTURE',
#  'SK_DPD_y']

# %%
#On va maintenant encoder les variables catégorielles
encoder = LabelEncoder()

for col in data_categ:
    X_train[col] = encoder.fit_transform(X_train[col])
    X_test[col] = encoder.fit_transform(X_test[col])

display(X_train)
# Out:
#         NAME_CONTRACT_TYPE  CODE_GENDER  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 182078                   0            0             0          130500.0
# 171974                   0            0             1          225000.0
# 197505                   0            0             0          157500.0
# 131372                   0            0             0          360000.0
# 140700                   0            0             0          108000.0
# ...                    ...          ...           ...               ...
# 180786                   0            1             1           90000.0
# 21579                    1            0             0           67500.0
# 96283                    0            0             2           90000.0
# 118942                   0            0             0          121500.0
# 134878                   0            0             2          112500.0
#
#         AMT_CREDIT_x  NAME_TYPE_SUITE  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# 182078     1170000.0                6                 1                    1
# 171974      432661.5                6                 1                    1
# 197505      342000.0                6                 1                    1
# 131372     1305000.0                6                 1                    1
# 140700      450000.0                6                 1                    1
# ...              ...              ...               ...                  ...
# 180786      807534.0                6                 1                    1
# 21579       202500.0                6                 1                    0
# 96283       550489.5                6                 1                    1
# 118942      239850.0                6                 1                    1
# 134878     1125000.0                1                 1                    1
#
#         NAME_FAMILY_STATUS  REGION_POPULATION_RELATIVE  ...  DAYS_DECISION  \
# 182078                   0                    0.035792  ...   -1899.000000
# 171974                   1                    0.031329  ...   -1229.250000
# 197505                   0                    0.018209  ...    -785.916667
# 131372                   0                    0.020246  ...   -1313.571429
# 140700                   1                    0.011657  ...   -1677.800000
# ...                    ...                         ...  ...            ...
# 180786                   0                    0.020246  ...    -688.000000
# 21579                    0                    0.014520  ...   -1496.000000
# 96283                    0                    0.010500  ...   -1638.666667
# 118942                   1                    0.024610  ...    -351.833333
# 134878                   0                    0.005002  ...   -1278.000000
#
#         CNT_PAYMENT  DAYS_FIRST_DRAWING  DAYS_LAST_DUE  DAYS_TERMINATION  \
# 182078    10.000000       365243.000000   -1582.000000      -1577.000000
# 171974     9.333333       365243.000000  120299.333333     120303.000000
# 197505     8.000000       313024.428571  103756.714286     103765.285714
# 131372    16.571429       365243.000000   51203.857143      51209.571429
# 140700     2.800000       242682.000000   -1572.333333     120890.000000
# ...             ...                 ...            ...               ...
# 180786    16.000000       365243.000000    -293.000000       -287.500000
# 21579     24.000000       365243.000000    -895.000000       -891.000000
# 96283     11.333333       365243.000000   -1376.666667      -1371.666667
# 118942    19.250000       365243.000000  145734.600000     145740.400000
# 134878    18.500000       365243.000000   90259.000000      -1057.750000
#
#         NAME_CONTRACT_STATUS  CODE_REJECT_REASON  NAME_CLIENT_TYPE  \
# 182078                     0                   7                 2
# 171974                     0                   7                 2
# 197505                     0                   7                 2
# 131372                     0                   7                 2
# 140700                     0                   7                 2
# ...                      ...                 ...               ...
# 180786                     0                   7                 2
# 21579                      0                   7                 1
# 96283                      0                   7                 2
# 118942                     0                   7                 2
# 134878                     0                   7                 2
#
#         CNT_INSTALMENT_FUTURE  SK_DPD_y
# 182078                    NaN       NaN
# 171974              11.000000       0.0
# 197505              10.700000       0.0
# 131372              15.272727       0.0
# 140700               5.090909       0.0
# ...                       ...       ...
# 180786               7.307692       0.0
# 21579                     NaN       NaN
# 96283                8.400000       0.0
# 118942              10.846154       0.0
# 134878              21.000000       0.0
#
# [246008 rows x 45 columns]

# %%
#Utilisation de la fonction avec le pipeline traitant les variables numériques
#Entrainement des variables numériques
preprocessor_fitted = Preprocessing(data_num).fit(X_train)
X_train_transformed = preprocessor_fitted.transform(X_train)
X_test_transformed = preprocessor_fitted.transform(X_test)

# %%
#On vérifie maintenant que les différentes transformations des types des colonnes ont bien eu lieu
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 246008 entries, 182078 to 134878
# Data columns (total 45 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   NAME_CONTRACT_TYPE           246008 non-null  int32
#  1   CODE_GENDER                  246008 non-null  int32
#  2   CNT_CHILDREN                 246008 non-null  int64
#  3   AMT_INCOME_TOTAL             246008 non-null  float64
#  4   AMT_CREDIT_x                 246008 non-null  float64
#  5   NAME_TYPE_SUITE              246008 non-null  int32
#  6   NAME_INCOME_TYPE             246008 non-null  int32
#  7   NAME_EDUCATION_TYPE          246008 non-null  int32
#  8   NAME_FAMILY_STATUS           246008 non-null  int32
#  9   REGION_POPULATION_RELATIVE   246008 non-null  float64
#  10  DAYS_BIRTH                   246008 non-null  int64
#  11  DAYS_EMPLOYED                246008 non-null  int64
#  12  OWN_CAR_AGE                  83633 non-null   float64
#  13  OCCUPATION_TYPE              246008 non-null  int32
#  14  CNT_FAM_MEMBERS              246006 non-null  float64
#  15  REGION_RATING_CLIENT         246008 non-null  int64
#  16  REGION_RATING_CLIENT_W_CITY  246008 non-null  int64
#  17  HOUR_APPR_PROCESS_START      246008 non-null  int64
#  18  REG_CITY_NOT_WORK_CITY       246008 non-null  int64
#  19  TOTALAREA_MODE               127351 non-null  float64
#  20  DEF_30_CNT_SOCIAL_CIRCLE     245192 non-null  float64
#  21  FLAG_DOCUMENT_3              246008 non-null  int64
#  22  AMT_REQ_CREDIT_BUREAU_YEAR   212826 non-null  float64
#  23  CREDIT_ACTIVE                246008 non-null  int32
#  24  DAYS_CREDIT                  210815 non-null  float64
#  25  AMT_CREDIT_SUM               210815 non-null  float64
#  26  AMT_BALANCE                  69610 non-null   float64
#  27  AMT_PAYMENT_CURRENT          48897 non-null   float64
#  28  SK_DPD_x                     69610 non-null   float64
#  29  SK_DPD_DEF                   69610 non-null   float64
#  30  DAYS_INSTALMENT_delay        201421 non-null  float64
#  31  AMT_INSTALMENT_delta         201421 non-null  float64
#  32  AMT_ANNUITY                  232516 non-null  float64
#  33  AMT_CREDIT_y                 232838 non-null  float64
#  34  AMT_DOWN_PAYMENT             218811 non-null  float64
#  35  DAYS_DECISION                232838 non-null  float64
#  36  CNT_PAYMENT                  232518 non-null  float64
#  37  DAYS_FIRST_DRAWING           231821 non-null  float64
#  38  DAYS_LAST_DUE                231821 non-null  float64
#  39  DAYS_TERMINATION             231821 non-null  float64
#  40  NAME_CONTRACT_STATUS         246008 non-null  int32
#  41  CODE_REJECT_REASON           246008 non-null  int32
#  42  NAME_CLIENT_TYPE             246008 non-null  int32
#  43  CNT_INSTALMENT_FUTURE        196079 non-null  float64
#  44  SK_DPD_y                     196226 non-null  float64
# dtypes: float64(26), int32(11), int64(8)
# memory usage: 76.0 MB

# %% [markdown]
# On voit que cela est conforme car nous n'avons plus que des variables numériques

# %%
print("Voici la taille du dataset X_test_transformed : ", X_test_transformed.shape)
# Out:
# Voici la taille du dataset X_test_transformed :  (61503, 45)

# %%
print("Voici la taille du dataset X_train_transformed : ", X_train_transformed.shape)
# Out:
# Voici la taille du dataset X_train_transformed :  (246008, 45)

# %%
#Création de dataframe avec X_train_transformed et X_test_transformed que l'on sauvegarde au format .CSV
pd.DataFrame(X_train_transformed).to_csv(path + 'X_train_transformed.csv',index=False)
pd.DataFrame(X_test_transformed).to_csv(path + 'X_test_transformed.csv',index=False)

# %% [markdown]
# ### Conclusion

# %% [markdown]
# On a donc pu réaliser un split avec un dataset de train et un de test que nous avons sauvegarder en CSV.
# Les datasets X_train_transformed et X_test_transformed permmettent d'avoir des datasets avec des variables catégorielles encodées pour préparer l'entrainement des modèles.
